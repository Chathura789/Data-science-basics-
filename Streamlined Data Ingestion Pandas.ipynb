# %% [markdown]
# ### 00 Part A Slides

# %% [markdown]
# https://drive.google.com/file/d/1ggLJFe0HhBfjvBaZ94JHNsiPKT1UU_wx/view?usp=sharing
# https://drive.google.com/file/d/1oyvKfQdidVU3PT1HUbo8Z0zpptPVEuSy/view?usp=sharing
# https://drive.google.com/file/d/1WOCGI_ITuX_1bp23EMO_TQWhqQNNL9j7/view?usp=sharing
# https://drive.google.com/file/d/1RpdqiWKWHoNruc9Igg2CZHdozPZ4zorP/view?usp=sharing

# %% [markdown]
# ### 00 Part B File imports

# %%
# !wget -O us_tax_data_2016.csv https://www.dropbox.com/s/v2r4yiqwfra68i0/us_tax_data_2016.csv?dl=0
# Out:
# --2020-10-24 06:12:31--  https://www.dropbox.com/s/v2r4yiqwfra68i0/us_tax_data_2016.csv?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.1, 2620:100:601f:1::a27d:901
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/v2r4yiqwfra68i0/us_tax_data_2016.csv [following]
# --2020-10-24 06:12:31--  https://www.dropbox.com/s/raw/v2r4yiqwfra68i0/us_tax_data_2016.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uca337d2638fcac1a8db84a5c476.dl.dropboxusercontent.com/cd/0/inline/BB084EUu_Q0kUC84HnvQ2L0Im2HGBcqVwvvVAuN1p_ERMR_2euuAWCKEcaV61JBoP2Gui1LUhUr9SwcUMnpWRAuupFldAgTdt6VCvMVxP0d6VVgcXuFJV5IASi73143tgM0/file# [following]
# ...

# %%
import pandas as pd 
tax_data = pd.read_csv('us_tax_data_2016.csv')

# %%
tax_data.head(1)
# Out:
#    STATEFIPS STATE  zipcode  agi_stub  ...  N11901  A11901  N11902  A11902
# 0         50    VT        0         1  ...   10820    9734   88260  138337
#
# [1 rows x 147 columns]

# %% [markdown]
# ###01 Importing Data from Flat Files

# %%
# Import pandas with the alias 
#import pandas as pd 
#import matplotlib.pyplot as plt
# Load TSV using the sep keyword argument to set delimiter
#data = pd.read_csv("vt_tax_data_2016.tsv", sep="\t")

# Plot the total number of tax returns by income group
counts = tax_data.groupby("agi_stub").N1.sum()
counts.plot.bar()
plt.show()

# %%
tax_data.shape
# Out:
# (1476, 147)

# %% [markdown]
# ### #Modifying flat file imports

# %% [markdown]
# ![image_2020-10-23_172436.png](data:image/png;base64,...)

# %%
#Limiting Columns this way we import only the required columns 
col_names =['STATEFIPS','STATE','zipcode','agi_stub','N1']

# %%
col_nums=[0,1,2,3,4]

# %%
tax_data_v1=tax_data = pd.read_csv('us_tax_data_2016.csv',usecols=col_names)
tax_data_v1.head(2)
# Out:
#    STATEFIPS STATE  zipcode  agi_stub      N1
# 0         50    VT        0         1  111580
# 1         50    VT        0         2   82760

# %%
tax_data_v2=tax_data = pd.read_csv('us_tax_data_2016.csv',usecols=col_nums)
tax_data_v2.head(2)
# Out:
#    STATEFIPS STATE  zipcode  agi_stub      N1
# 0         50    VT        0         1  111580
# 1         50    VT        0         2   82760

# %%
#are the two dataframes equal 
print(tax_data_v1.equals(tax_data_v2))
# Out:
# True

# %%
#the nrows keyword arg can limit injested rows 
tax_data_v3=tax_data = pd.read_csv('us_tax_data_2016.csv',nrows=50)
tax_data_v3.head(2)
tax_data_v3.shape
# Out:
# (50, 147)

# %%
tax_data_v1.shape
# Out:
# (1476, 5)

# %%
print(tax_data_v1.equals(tax_data_v3))
# Out:
# False

# %%
#Exercises after video "modification of flat file imports"

# %%
# Create list of columns to use
cols = ["zipcode", "agi_stub", "mars1", "MARS2", "NUMDEP"]

# Create data frame from csv using only selected columns
data = pd.read_csv("us_tax_data_2016.csv", usecols=cols)

# View counts of dependents and tax returns by income level
print(data.groupby("agi_stub").sum())
# Out:
#           zipcode   mars1  MARS2  NUMDEP
# agi_stub
# 1         1439444  170320  28480   52490
# 2         1439444  104000  37690   64660
# 3         1439444   39160  45390   47330
# 4         1439444   11670  44410   37760
# 5         1439444    7820  67750   60730
# 6         1439444    1210  16340   16300

# %%
# Create data frame of next 500 rows with labeled columns
data_first50 = pd.read_csv("us_tax_data_2016.csv", 
                       		  nrows=500,
                       	                       	)

# %%
data_first50.head(12)
# Out:
#     STATEFIPS STATE  zipcode  agi_stub  ...  N11901  A11901  N11902  A11902
# 0          50    VT        0         1  ...   10820    9734   88260  138337
# 1          50    VT        0         2  ...   12820   20029   68760  151729
# 2          50    VT        0         3  ...   10810   24499   34600   90583
# 3          50    VT        0         4  ...    7320   21573   21300   67045
# 4          50    VT        0         5  ...   12500   67761   23320  103034
# 5          50    VT        0         6  ...    3900   93123    2870   39425
# 6          50    VT     5001         1  ...     120     102    1080    1662
# 7          50    VT     5001         2  ...     160     269     890    1814
# 8          50    VT     5001         3  ...     110     220     460    1215
# 9          50    VT     5001         4  ...      90     293     250     798
# 10         50    VT     5001         5  ...     130     615     290    1262
# ...

# %%
#Next say 500 rows 
data_next500 = pd.read_csv("us_tax_data_2016.csv", 
                       		  nrows=500,
                       		  skiprows=50,
                       		  header=None,
                       		  names=list(data_first50))

# %%
# View the Vermont data frames to confirm they're different
print(data_first50.head(2))
# Out:
#    STATEFIPS STATE  zipcode  agi_stub  ...  N11901  A11901  N11902  A11902
# 0         50    VT        0         1  ...   10820    9734   88260  138337
# 1         50    VT        0         2  ...   12820   20029   68760  151729
#
# [2 rows x 147 columns]

# %%
print(data_next500.head())
# Out:
#    STATEFIPS STATE  zipcode  agi_stub  ...  N11901  A11901  N11902  A11902
# 0         50    VT     5037         2  ...       0       0      80     151
# 1         50    VT     5037         3  ...      20      53      50     137
# 2         50    VT     5037         4  ...       0       0      40     111
# 3         50    VT     5037         5  ...      30     375      50     271
# 4         50    VT     5037         6  ...       0       0       0       0
#
# [5 rows x 147 columns]

# %% [markdown]
# ## Handling errors and missing data

# %%
# # there can be errors as per below when importing 
# 1- coulumn data types are wrong 
# 2-missing values custom values denoting this 
# 3-record that cannot be read by pandas

# %%
#Lets see what we can do about these

# %%
# 01- Specify data type 
# in this example a string 
data = pd.read_csv("us_tax_data_2016.csv",dtype={"zipcode" : str})

# %%
#pandas objects means str 
print(data.dtypes)
# Out:
# STATEFIPS     int64
# STATE        object
# zipcode      object
# agi_stub      int64
# N1            int64
#               ...
# A85300        int64
# N11901        int64
# A11901        int64
# N11902        int64
# A11902        int64
# Length: 147, dtype: object

# %%
data = pd.read_csv('us_tax_data_2016.csv',na_values={"zipcode":0})

# %%
#see how now the 0 zipcodes are flagged as Nan
data.head(4)
# Out:
#    STATEFIPS STATE  zipcode  agi_stub  ...  N11901  A11901  N11902  A11902
# 0         50    VT      NaN         1  ...   10820    9734   88260  138337
# 1         50    VT      NaN         2  ...   12820   20029   68760  151729
# 2         50    VT      NaN         3  ...   10810   24499   34600   90583
# 3         50    VT      NaN         4  ...    7320   21573   21300   67045
#
# [4 rows x 147 columns]

# %%
# view the Nan Data Only 
print(data[data.zipcode.isna()])
# Out:
#    STATEFIPS STATE  zipcode  agi_stub  ...  N11901  A11901  N11902  A11902
# 0         50    VT      NaN         1  ...   10820    9734   88260  138337
# 1         50    VT      NaN         2  ...   12820   20029   68760  151729
# 2         50    VT      NaN         3  ...   10810   24499   34600   90583
# 3         50    VT      NaN         4  ...    7320   21573   21300   67045
# 4         50    VT      NaN         5  ...   12500   67761   23320  103034
# 5         50    VT      NaN         6  ...    3900   93123    2870   39425
#
# [6 rows x 147 columns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Lines with Errors 
#If the data actually had unparsable line python will show something like below 
# if you want null values to be Nan then 'na_values=null_values' in the read csv argument 

data = pd.read_csv('us_tax_data_2016.csv',na_values={"zipcode":0},error_bad_lines=False,warn_bad_lines=True)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Additional readings
# https://stackoverflow.com/questions/41962629/n-a-as-n-a-not-as-not-a-number-in-pandas-and-python
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 02 Importing Data From Excel Files

# %%
import pandas as pd

# %%
# !wget -O fcc_new_coder_survey.xlsx https://www.dropbox.com/s/uqzjd5x0zyjx67v/fcc_new_coder_survey.xlsx?dl=0
# Out:
# --2020-10-25 02:20:30--  https://www.dropbox.com/s/uqzjd5x0zyjx67v/fcc_new_coder_survey.xlsx?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.1, 2620:100:6022:1::a27d:4201
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/uqzjd5x0zyjx67v/fcc_new_coder_survey.xlsx [following]
# --2020-10-25 02:20:31--  https://www.dropbox.com/s/raw/uqzjd5x0zyjx67v/fcc_new_coder_survey.xlsx
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucadec3baa142bbb2c9fd0249e7f.dl.dropboxusercontent.com/cd/0/inline/BB5_OPxe3zEyMSrFLOHQpgHaQOtBor-oaR40Jz3HwnKpyfMnR451YtoIkEh6NtaCzO-5Yz7EtGsAfGDwVQVYLyWL9N9VRWlhB_efr9N6RDOIvv_LOxvUysjFW7M4nbFkcSg/file# [following]
# ...

# %%
sr=survey_responses = pd.read_excel("fcc_new_coder_survey.xlsx")

# %%
survey_responses.head(3)
# Out:
#    FreeCodeCamp New Developer Survey Responses, 2016  ...     Unnamed: 97
# 0  Source: https://www.kaggle.com/freecodecamp/20...  ...             NaN
# 1                                                Age  ...  StudentDebtOwe
# 2                                                 28  ...           20000
#
# [3 rows x 98 columns]

# %%
#new import with only proper cols & skips top rows 
col_string = "AD, AW:BA"

# Load data with skiprows and usecols set
survey_responses = sr=pd.read_excel("fcc_new_coder_survey.xlsx", 
                                 skiprows=2, 
                                 usecols=col_string)

# View the names of the columns selected
print(survey_responses.columns)
# Out:
# Index(['ExpectedEarning', 'JobApplyWhen', 'JobPref', 'JobRelocateYesNo',
#        'JobRoleInterest', 'JobWherePref'],
#       dtype='object')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# GET SECOND SHEET Y POSITION INDEX 
survey_responses = sr1=pd.read_excel("fcc_new_coder_survey.xlsx",sheet_name=1)

survey_responses2 = sr2=pd.read_excel("fcc_new_coder_survey.xlsx",sheet_name='2017')


print(sr1.equals(sr2))
# Out:
# True

# %%
#Loading all sheets

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
survey_responsesall = srall=pd.read_excel("fcc_new_coder_survey.xlsx",sheet_name=None,skiprows=2)

# %%
#so the above pull a dictionary 
#notice we get an ordered dictionary  
print(type(srall))
# Out:
# <class 'dict'>

# %%
# then notice keys are sheet names and values are dataframes

# %%
for key , value in srall.items():
    print(key , type(value))
# Out:
# 2016 <class 'pandas.core.frame.DataFrame'>
# 2017 <class 'pandas.core.frame.DataFrame'>

# %%
#Neater way to get all the keys 
print(srall.keys())
# Out:
# dict_keys(['2016', '2017'])

# %%
# since each sheet has the same data we need to union them 
sr_alldf=pd.DataFrame()

# %%
# Set up for loop to iterate through values in responses
for df in srall.values():
  # Print the number of rows being added
  print("Adding {} rows".format(df.shape[0]))
  # Append df to all_responses, assign result
  sr_alldf = sr_alldf.append(df)
# Out:
# Adding 1000 rows
# Adding 1000 rows

# %%
sr_alldf.head(2)
# Out:
#     Age  AttendedBootcamp  ...  SchoolMajor  StudentDebtOwe
# 0  28.0               0.0  ...          NaN           20000
# 1  22.0               0.0  ...          NaN             NaN
#
# [2 rows x 98 columns]

# %%
counts = sr_alldf.groupby("EmploymentStatus").EmploymentStatus.count().sort_values(ascending=False)
print(counts)
# Out:
# EmploymentStatus
# Employed for wages                      1013
# Not working but looking for work         378
# Self-employed freelancer                 129
# Not working and not looking for work     127
# Self-employed business owner              71
# Doing an unpaid internship                55
# A stay-at-home parent or homemaker        35
# Unable to work                            31
# Military                                   9
# Retired                                    8
# Name: EmploymentStatus, dtype: int64

# %%
 import matplotlib.pyplot as plt
counts.sort_values().plot.barh()
plt.show()

# %% [markdown]
# # Handling Boolean Data

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## revise boolean section & improve

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !wget -O fcc_new_coder_survey_mod.xlsx https://www.dropbox.com/s/648n9yfmrpf45n9/fcc-new-coder-survey_mod_bool.xlsx?dl=0
# Out:
# --2020-10-25 08:24:48--  https://www.dropbox.com/s/648n9yfmrpf45n9/fcc-new-coder-survey_mod_bool.xlsx?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.1, 2620:100:6021:1::a27d:4101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/648n9yfmrpf45n9/fcc-new-coder-survey_mod_bool.xlsx [following]
# --2020-10-25 08:24:48--  https://www.dropbox.com/s/raw/648n9yfmrpf45n9/fcc-new-coder-survey_mod_bool.xlsx
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc0e738261b5c6ba5dc28289da89.dl.dropboxusercontent.com/cd/0/inline/BB4DwFMfBfw7UthMMW6h0q_GVE_OXCsnK7JtirshRuHDaEXf-i1VSUUrMUjbT5PPmeRDdKtncUQXGNg0LgU8-r0TKnc09BVENY93F7tfLEwt67L7T8ujWP6Ry8_aYERuyt4/file# [following]
# ...

# %%
srbool=pd.read_excel("fcc_new_coder_survey_mod.xlsx")

# %%
srbool.head(3)
# Out:
#                                ID.x  ... BootcampLoanYesNo
# 0  cef35615d61b202f1dc794ef2746df14  ...               NaN
# 1  323e5a113644d18185c743c241407754  ...               NaN
# 2  b29a1027e5cd062e654a63764157461d  ...               NaN
#
# [3 rows x 9 columns]

# %%
#notice the data type was not boolean 
srbool.dtypes
# Out:
# ID.x                      object
# ID.y                      object
# Year                       int64
# AttendedBootcamp         float64
# BootcampLoan             float64
# AttendedBootcampTF       float64
# BootcampLoanTF           float64
# AttendedBootcampYesNo     object
# BootcampLoanYesNo         object
# dtype: object

# %%
print(srbool.sum())
# Out:
# ID.x                  cef35615d61b202f1dc794ef2746df14323e5a113644d1...
# ID.y                  48fd66e15301df9727e13e6e80aef941a8cd6719318408...
# Year                                                            4033000
# AttendedBootcamp                                                    166
# BootcampLoan                                                         53
# AttendedBootcampTF                                                  166
# BootcampLoanTF                                                       53
# dtype: object

# %%
#Extra TIP

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#check how many values are missing 
print(srbool.isna().sum())
# Out:
# ID.x                        0
# ID.y                        0
# Year                        0
# AttendedBootcamp           20
# BootcampLoan             1836
# AttendedBootcampTF         20
# BootcampLoanTF           1836
# AttendedBootcampYesNo      20
# BootcampLoanYesNo        1836
# dtype: int64

# %%
print(srbool.columns)
'AttendedBootcamp'
'BootcampLoanYesNo'
# Out:
# Index(['ID.x', 'ID.y', 'Year', 'AttendedBootcamp', 'BootcampLoan',
#        'AttendedBootcampTF', 'BootcampLoanTF', 'AttendedBootcampYesNo',
#        'BootcampLoanYesNo'],
#       dtype='object')
# 'BootcampLoanYesNo'

# %%
import numpy as np

# %%
srbool=pd.read_excel('fcc_new_coder_survey_mod.xlsx', dtype ={'AttendedBootcamp':bool,
                               'BootcampLoan':bool,
       'AttendedBootcampTF':bool, 
       'BootcampLoanTF':bool, 
       'AttendedBootcampYesNo':bool,
       'BootcampLoanYesNo':bool
}, true_values=["Yes"],false_values=["No"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-494da1e6d82a> in <module>()
#       5        'AttendedBootcampYesNo':bool,
#       6        'BootcampLoanYesNo':bool
# ----> 7 }, true_values=["Yes"],false_values=["No"])
#       8
#       9
#
# /usr/local/lib/python3.6/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ...

# %%
print(srbool.head(3))
# Out:
#                                ID.x  ... BootcampLoanYesNo
# 0  cef35615d61b202f1dc794ef2746df14  ...             False
# 1  323e5a113644d18185c743c241407754  ...             False
# 2  b29a1027e5cd062e654a63764157461d  ...             False
#
# [3 rows x 9 columns]

# %%
print(srbool.isna().sum())
# Out:
# ID.x                     0
# ID.y                     0
# Year                     0
# AttendedBootcamp         0
# BootcampLoan             0
# AttendedBootcampTF       0
# BootcampLoanTF           0
# AttendedBootcampYesNo    0
# BootcampLoanYesNo        0
# dtype: int64

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #[Handling Date time columns ](https://)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#formats https://www.programiz.com/python-programming/datetime/strftime

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 03 Importing Data from Databases

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !wget -O fcc_new_coder_survey_mod_time.xlsx https://www.dropbox.com/s/u3wl8niwbi2o3fv/fcc_new_coder_survey_mod_time.xlsx?dl=0
# Out:
# --2020-10-25 09:26:34--  https://www.dropbox.com/s/u3wl8niwbi2o3fv/fcc_new_coder_survey_mod_time.xlsx?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.1, 2620:100:6021:1::a27d:4101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/u3wl8niwbi2o3fv/fcc_new_coder_survey_mod_time.xlsx [following]
# --2020-10-25 09:26:34--  https://www.dropbox.com/s/raw/u3wl8niwbi2o3fv/fcc_new_coder_survey_mod_time.xlsx
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucebc3dc68360599bb3b34f10a87.dl.dropboxusercontent.com/cd/0/inline/BB74NaG7jpFLIdCWpe13lKIB_GZVzsBoKlCSyngL-mrlAKxSfEGR1nG1s9pjrMa4ctrzm78KRqao7ice1EgqGpB6XSubAnA1ISFeCVaPFfWErg4T7RlYxm1uwyUrAY7KIr8/file# [following]
# ...

# %%
srtime=pd.read_excel('fcc_new_coder_survey_mod_time.xlsx')

# %%
srtime.head(3)
# Out:
#                                ID.x  ...    Part3Time
# 0  cef35615d61b202f1dc794ef2746df14  ...  29 21:24:57
# 1  323e5a113644d18185c743c241407754  ...  29 21:27:14
# 2  b29a1027e5cd062e654a63764157461d  ...  29 21:27:13
#
# [3 rows x 7 columns]

# %%
srtime.dtypes
# Out:
# ID.x              object
# Part1EndTime      object
# Part1StartTime    object
# Part2EndTime      object
# Part2StartTime    object
# Part3Date          int64
# Part3Time         object
# dtype: object

# %%
print(srtime.columns)
'AttendedBootcamp'
'BootcampLoanYesNo'
# Out:
# Index(['ID.x', 'Part1EndTime', 'Part1StartTime', 'Part2EndTime',
#        'Part2StartTime', 'Part3Date ', 'Part3Time'],
#       dtype='object')
# 'BootcampLoanYesNo'

# %%
#compact way to rename columns to lower i first thought nwcol didnt work because items not in lowercase turns out there was a space in column 'Part3Date '
srtime= srtime.rename(columns=str.lower)

# %%
#converto date time at time of import 
date_columns = ['Part1EndTime', 'Part1StartTime', 'Part2EndTime','Part2StartTime']
srtime = pd.read_excel('fcc_new_coder_survey_mod_time.xlsx', parse_dates=date_columns)

# %%
srtime.dtypes
# Out:
# ID.x                      object
# Part1EndTime      datetime64[ns]
# Part1StartTime    datetime64[ns]
# Part2EndTime      datetime64[ns]
# Part2StartTime    datetime64[ns]
# Part3Date         datetime64[ns]
# Part3Time                 object
# dtype: object

# %%
# all except 3rd column done convert that to a nwcol string dont forget the space or unknown format

# %%
srtime['nwcol']=srtime['Part3Date '].astype(str) +' '+ srtime['Part3Time']

# %%
srtime['nwcol']=pd.to_datetime(srtime['nwcol'])

# %%
srtime.head(2)
# Out:
#                                ID.x  ...               nwcol
# 0  cef35615d61b202f1dc794ef2746df14  ... 2016-03-29 21:24:57
# 1  323e5a113644d18185c743c241407754  ... 2016-03-29 21:27:14
#
# [2 rows x 8 columns]

# %%
srtime.dtypes
# Out:
# ID.x                      object
# Part1EndTime      datetime64[ns]
# Part1StartTime    datetime64[ns]
# Part2EndTime      datetime64[ns]
# Part2StartTime    datetime64[ns]
# Part3Date         datetime64[ns]
# Part3Time                 object
# nwcol             datetime64[ns]
# dtype: object

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# a much neater wayt to do the above
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### #Eg : on parsing a non std format

# %%
# # Parse datetimes and assign result back to Part2EndTime
# survey_data["Part2EndTime"] = pd.to_datetime(survey_data["Part2EndTime"], 
#                                              format="%m%d%Y %H:%M:%S")

# # Print first few values of Part2EndTime
# print(survey_data.Part2EndTime.head())

# %% [markdown]
# ## 03 Importing Data from Databases

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#https://docs.google.com/document/d/1V3os_7G0wA4S5-wzCI64e_XmA8VA0LVJpvwenkgtWSA/edit?usp=sharing

# %%
# Find a way to connect to an online data set & get the data into here to replace the above word file link

# %% [markdown]
# ## 04 Importing JSON Data and Working with APIs

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Get Data from an Api 
api_url = "https://api.yelp.com/v3/businesses/search"

# %%
# Get data about NYC cafes from the Yelp API
response = requests.get(api_url, 
                        headers=headers, 
                        params=params)

# Extract JSON data from the response
data = response.json()

# Load data to a data frame
cafes = pd.DataFrame(data["businesses"])

# View the data's dtypes
print(cafes.dtypes)

# %%
## Since no API key need refer word file

# %%
# https://docs.google.com/document/d/1V3os_7G0wA4S5-wzCI64e_XmA8VA0LVJpvwenkgtWSA/edit?usp=sharing

# %% [markdown]
# ## POSTGRES CONNECTOR TUTORIAL

# %%
# https://pypi.org/project/psycopg2/
# https://pynative.com/python-postgresql-tutorial/
