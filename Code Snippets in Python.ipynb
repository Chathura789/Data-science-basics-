# %%
#Synching google drive & dropbox 
#https://www.bettercloud.com/monitor/the-academy/how-to-add-google-drive-files-to-dropbox/

# %%
#Next Courses 
#https://learn.datacamp.com/courses/streamlined-data-ingestion-with-pandas
#https://learn.datacamp.com/courses/joining-data-with-pandas
#https://learn.datacamp.com/courses/introduction-to-relational-databases-in-python
#https://learn.datacamp.com/courses/streaming-data-with-aws-kinesis-and-lambda

# %%
https://stackoverflow.com/questions/20906474/import-multiple-csv-files-into-pandas-and-concatenate-into-one-dataframe
import pandas as pd
import glob

path = r'C:\DRO\DCL_rawdata_files' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
r code 
diagnose 
https://cran.r-project.org/web/packages/dlookr/vignettes/diagonosis.html

# %%
#Union a set of Data in One path

# %%
#Sidetable 
#https://pbpython.com/sidetable.html

# %%
#Merging 
#https://www.shanelynn.ie/merge-join-dataframes-python-pandas-index-1/

# %%
#Reading poorly structured excel data python 
#https://pbpython.com/pandas-excel-range.html

# %%
fuzzy string search 
https://www.datacamp.com/community/tutorials/fuzzy-string-python
