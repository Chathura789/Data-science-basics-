# %%
# machine learning fundamentals 
# https://learn.datacamp.com/skill-tracks/machine-learning-fundamentals-with-python

# %%
# !pip install scikit-learn as sklearn

# %%
import sklearn as sk

# %%
import pandas as pd

# %%
#Datasetimporting

# %%
# !wget -O Boston.csv https://www.dropbox.com/s/fm7xyvrjlopq9jk/Boston.csv?dl=0

boston = pd.read_csv('Boston.csv')
# Out:
# --2021-04-24 12:55:07--  https://www.dropbox.com/s/fm7xyvrjlopq9jk/Boston.csv?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.18, 2620:100:6016:18::a27d:112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/fm7xyvrjlopq9jk/Boston.csv [following]
# --2021-04-24 12:55:07--  https://www.dropbox.com/s/raw/fm7xyvrjlopq9jk/Boston.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc3ea68f0e767d5c70309a88a0f8.dl.dropboxusercontent.com/cd/0/inline/BNM6KqMtkiFLTslVvkAd0srCqUY7UyVJAot_DEjAI20XvK7C-nCYNDiRVcb7WYtDEaMa9Exx5QvlHwBzu-Cht0TepXKUqo_K7Si8S49FBukBOc49gf1Ww6e5oV3THhiW_kewC9t4NROpBNQklPwN8inv/file# [following]
# ...

# %%
# !wget -O diabetes.csv https://www.dropbox.com/s/uo6aooe5iwr3p8o/diabetes.csv?dl=0l=0

diabetes = pd.read_csv('diabetes.csv')
# Out:
# --2021-04-21 16:29:01--  https://www.dropbox.com/s/uo6aooe5iwr3p8o/diabetes.csv?dl=0l=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:6018:18::a27d:312
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/uo6aooe5iwr3p8o/diabetes.csv [following]
# --2021-04-21 16:29:01--  https://www.dropbox.com/s/raw/uo6aooe5iwr3p8o/diabetes.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc5de2c87bce0bfd71a6f19486ab.dl.dropboxusercontent.com/cd/0/inline/BNCa33UYmaD0TMA1GWJXRS0XIYCBREFe7OSHU4c2BzreDC24QgyQA5IWUkW77jHUK6ianAZXpNEGTYSuIq2NMb0DBUAgp-qu5-NVuUOyJijIm5MGUh4qwjU8k9SaHo5swOnV82OkzMyxQ51_Q-vufvp0/file# [following]
# ...

# %%
# !wget -O gapminder.csv https://www.dropbox.com/s/au5xt886qugsv1x/gapminder.csv?dl=0

gapminder = pd.read_csv('gapminder.csv')
# Out:
# --2021-04-21 16:29:03--  https://www.dropbox.com/s/au5xt886qugsv1x/gapminder.csv?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:6018:18::a27d:312
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/au5xt886qugsv1x/gapminder.csv [following]
# --2021-04-21 16:29:03--  https://www.dropbox.com/s/raw/au5xt886qugsv1x/gapminder.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc538145a2ae7ad88c420442527e.dl.dropboxusercontent.com/cd/0/inline/BNANJPzml0-L5lbMN8ogovVSiHef2q90uGMvAEOHTAC-QPefqr0myGeB8EFOpcpOb9tVLIxoHHXRv5Elq0pUOFIMZjpmMYm1a0qaz0kPd_RIGyevNvLcLvEjP_FkNMfON0k9-5WgA8vsufG_fw6u1NKi/file# [following]
# ...

# %%
# !wget -O house_votes.csv https://www.dropbox.com/s/iqt0si8ib23av9o/house_votes.csv?dl=0

housevotes = pd.read_csv('house_votes.csv')
# Out:
# --2021-04-21 16:29:06--  https://www.dropbox.com/s/iqt0si8ib23av9o/house_votes.csv?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:6018:18::a27d:312
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/iqt0si8ib23av9o/house_votes.csv [following]
# --2021-04-21 16:29:06--  https://www.dropbox.com/s/raw/iqt0si8ib23av9o/house_votes.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc6f0bd61c696e58772ef9fb04d7.dl.dropboxusercontent.com/cd/0/inline/BNCj3fq1iIh18DvNfBuYN2cTuAUorVrmjhouZwu0z7Ny35Gs9ocg9SEmjx8vkryX9GDU11OiPMeVReb3SsAAUkoXUWRCw1NOeV38M1lOypBQ84onP2_kgxt4RbigGFCQWbwlyisgQdx0deJFHqa_aNzy/file# [following]
# ...

# %%
# !wget -O mpg.csv https://www.dropbox.com/s/wh4w9grpkpuii69/mpg.csv?dl=0

mpg = pd.read_csv('mpg.csv')
# Out:
# --2021-04-21 16:29:09--  https://www.dropbox.com/s/wh4w9grpkpuii69/mpg.csv?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:6018:18::a27d:312
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/wh4w9grpkpuii69/mpg.csv [following]
# --2021-04-21 16:29:09--  https://www.dropbox.com/s/raw/wh4w9grpkpuii69/mpg.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucf17c187a54c9fbde6cd4f01be1.dl.dropboxusercontent.com/cd/0/inline/BNBQ98rP42FDeuIZi43n3BilVA13JMLWU-X_y1zKzq2HJkUuuWg50G7luvaNKmxAg8FQRTx6QnY_FPeNG8hroLfXPTGfWDb8OgjkehP028xq-RVzkkFCpTBwDtLZh5JR0Cppprcw8K40t391NnddYmQK/file# [following]
# ...

# %%
# !wget -O white_wine.csv https://www.dropbox.com/s/omswm93cjhad8vs/white_wine.csv?dl=0

whitewine = pd.read_csv('white_wine.csv')
# Out:
# --2021-04-21 16:29:11--  https://www.dropbox.com/s/omswm93cjhad8vs/white_wine.csv?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:601b:18::a27d:812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/omswm93cjhad8vs/white_wine.csv [following]
# --2021-04-21 16:29:11--  https://www.dropbox.com/s/raw/omswm93cjhad8vs/white_wine.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uce19f261c80f83c28409853f788.dl.dropboxusercontent.com/cd/0/inline/BNDTutgGrc84rr_f5fPpBxrkeSD7ePjpat0Q4BrE9i91-hLD0haSnlLzd_3wTt9OcgHvOefzgWujujglieDZvo-SgfwuFtulE7sPaJtiJNrHYLKWNLs-Cu7V7XtuxdBLFNlv0shlaUPeaOvJrf38vF8M/file# [following]
# ...

# %%
# !wget -O winequality_red.csv https://www.dropbox.com/s/zyhz92cla1j6yh3/winequality_red.csv?dl=0

redwine = pd.read_csv('winequality_red.csv',sep=";")
# Out:
# --2021-04-21 16:29:15--  https://www.dropbox.com/s/zyhz92cla1j6yh3/winequality_red.csv?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:601b:18::a27d:812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/zyhz92cla1j6yh3/winequality_red.csv [following]
# --2021-04-21 16:29:15--  https://www.dropbox.com/s/raw/zyhz92cla1j6yh3/winequality_red.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uceeb4958ed69d419b82def28125.dl.dropboxusercontent.com/cd/0/inline/BNDxJiS6z8QvWHW8ha2vyff5pJr5lRPY980FuxuB4gTjIOVuArQwOYErzpVwWqYbuzg0Cb-_z_nLt_QdyNsHZNfk-xDA6fEVOq_b2B4PL7MKnr8eiZhC0yF2H-tFSxDvaGi06Cr4Y3AiLgRlU36IOpDY/file# [following]
# ...

# %%
boston.head(2)
# Out:
#       CRIM    ZN  INDUS  CHAS     NX  ...    TAX  PTRATIO      B  LSTAT  MEDV
# 0  0.00632  18.0   2.31     0  0.538  ...  296.0     15.3  396.9   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242.0     17.8  396.9   9.14  21.6
#
# [2 rows x 14 columns]

# %%
diabetes.head(2)
# Out:
#    pregnancies  glucose  diastolic  triceps  ...   bmi    dpf  age  diabetes
# 0            6      148         72       35  ...  33.6  0.627   50         1
# 1            1       85         66       29  ...  26.6  0.351   31         0
#
# [2 rows x 9 columns]

# %%
gapminder.head(2)
# Out:
#    population  fertility  ...  child_mortality                      Region
# 0  34811059.0       2.73  ...             29.5  Middle East & North Africa
# 1  19842251.0       6.43  ...            192.0          Sub-Saharan Africa
#
# [2 rows x 10 columns]

# %%
#Housevotes needs headders 
#remember 
housevotes.head(2)

# %%
housevotes.columns = ['party', 'infants', 'water', 'budget', 'physician', 'salvador',
       'religious', 'satellite', 'aid', 'missile', 'immigration', 'synfuels',
       'education', 'superfund', 'crime', 'duty_free_exports', 'eaa_rsa']

# %%
housevotes.head(2)
# Out:
#    republican  n  y n.1 y.1 y.2 y.3 n.2 n.3 n.4 y.4  ? y.5 y.6 y.7 n.5 y.8
# 0  republican  n  y   n   y   y   y   n   n   n   n  n   y   y   y   n   ?
# 1    democrat  ?  y   y   ?   y   y   n   n   n   n  y   n   y   y   n   n

# %%
hv.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-f7862592783c> in <module>()
# ----> 1 hv.head(2)
#
# NameError: name 'hv' is not defined

# %%
mpg.head(2)
# Out:
#     mpg  displ   hp  weight  accel origin  size
# 0  18.0  250.0   88    3139   14.5     US  15.0
# 1   9.0  304.0  193    4732   18.5     US  20.0

# %%
whitewine.head(2)
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.0              0.27         0.36  ...       0.45      8.8        6
# 1            6.3              0.30         0.34  ...       0.49      9.5        6
#
# [2 rows x 12 columns]

# %%
redwine.head(2)
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70          0.0  ...       0.56      9.4        5
# 1            7.8              0.88          0.0  ...       0.68      9.8        5
#
# [2 rows x 12 columns]

# %%
# !wget -O iris.csv https://www.dropbox.com/s/kfdjuef6hk9w95z/Iris.csv?dl=0
# Out:
# --2021-04-21 16:35:50--  https://www.dropbox.com/s/kfdjuef6hk9w95z/Iris.csv?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:601b:18::a27d:812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/kfdjuef6hk9w95z/Iris.csv [following]
# --2021-04-21 16:35:50--  https://www.dropbox.com/s/raw/kfdjuef6hk9w95z/Iris.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc7d073a3238692ddc44c3896c9c.dl.dropboxusercontent.com/cd/0/inline/BNC13je0p4wepVTFcFSFjc05MdyGaZX9l6eEIRaoT68e3vpF3IB8QhEWEwthTC5WIhRnZfQJQyZOPD3gGX2rorfIqCYMzup5LyuT_bUk_mTAU588HnJr03QscIMCr6L5Mm_BQu7wBCoeAOvqCXxXVJeE/file# [following]
# ...

# %%
iris = pd.read_csv('iris.csv')


iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
