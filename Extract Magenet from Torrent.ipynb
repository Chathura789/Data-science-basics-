# %%
rargb = requests.get('https://rarbg.to/torrent/k2fucth').text

# %%
link = BeautifulSoup(rargb,'lxml')

# %%
print(link)

# %%
import regex as re

# %%
link= rargb.find_all(re.compile("magnet:?"))

# %% [markdown]
# for tag in soup.find_all(re.compile("t")):
#     print(tag.name)

# %%
print(link.prettify())


for link in soup.find_all(re.compile("magnet:?"))
